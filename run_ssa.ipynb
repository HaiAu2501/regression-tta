# %%
# %pip install -r requirements.txt

# %%
# %run download.py

# %% [markdown]
# # 1. DATASET: SVHN → MNIST

# %%
# %run train_source.py -c configs/train_source/svhn.yaml -o result/source/svhn

# %%
# %run feature_stats.py -c configs/feature_stats/svhn.yaml -o result/source/svhn

# %%
# %run adaptation.py -c configs/tta/svhn.yaml -o result/tta/svhn

# %% [markdown]
# # 2. DATASET: UTKFace → UTKFace 13 corruptions

# %%
# %run train_source.py -c configs/train_source/utkface.yaml -o result/source/utkface

# %%
# %run feature_stats.py -c configs/feature_stats/utkface.yaml -o result/source/utkface

# %%
# %run adaptation.py -c configs/tta/utkface.yaml -o result/tta/utkface
